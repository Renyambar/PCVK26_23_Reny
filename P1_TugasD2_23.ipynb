# %% [markdown]
# <a href="https://colab.research.google.com/github/Renyambar/PCVK26_23_Reny/blob/main/P1_TugasD2_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://cdn.wallpapersafari.com/61/6/cbhPR0.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=1600x500>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi," x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  500  x  800
# <PIL.Image.Image image mode=RGB size=800x500>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for y in range(tinggi):
  #membuat garis horizontal di tengah image
  for y in range(lebar):
    image_3[int((tinggi)/2),y] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x500>

# %% [markdown]
# PERTANYAAN PRAKTIKUM D2
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#     Agar tidak perlu instalasi Python/library di laptop masing-masing, gratis akses GPU, dan bisa diakses dari mana saja
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
#
# * numpy as np: mengolah citra sebagai array numerik (operasi
# matriks, indexing piksel, dll)
# * pandas as pd:	mengolah data dalam bentuk tabel (misal menyimpan/menampilkan metadata atau hasil analisis)
# * cv2 as cv (OpenCV):	library utama untuk membaca, memproses, dan memanipulasi citra (resize, filter, deteksi tepi, dll)
# * cv2_imshow (dari google.colab.patches): menampilkan citra di Google Colab, karena cv2.imshow() biasa tidak berjalan di lingkungan Colab
# * skimage.io:	Alternatif untuk membaca/menyimpan file citra
# * skimage.transform: Menyediakan fungsi transformasi citra (resize, rotate, rescale, dll) sebagai alternatif dari OpenCV
# * PIL.Image	Library lain untuk membuka, mengedit, dan menyimpan berbagai format citra
# * matplotlib.pylab as plt: Menampilkan citra dan grafik/plot hasil pengolahan
#
#
#   Tidak harus digunakan semuanya karena beberapa library ini fungsinya sama misalnya cv2, skimage, dan PIL sama-sama bisa membaca/resize citra. Import di atas kemungkinan mencakup semua kebutuhan berbagai langkah dalam satu notebook, tapi di setiap langkah biasanya hanya sebagian yang benar-benar dipakai, tergantung fungsi spesifik yang dijalankan pada langkah tersebut.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
#     Mengubah ukuran citra berdasarkan skala (50% dari ukuran asli lebar & tinggi), bukan piksel absolut. Jika tidak dilakukan, citra tetap ukuran asli sehingga proses lebih lambat, memori lebih besar, dan bisa error jika butuh ukuran sama dengan citra lain.
#
# 4. Perhatikan potongan kode progam berikut :
#   Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
#     Itu nilai warna putih (RGB/BGR maksimum). Kode ini mengisi seluruh piksel pada baris tengah citra dengan warna putih, sehingga terbentuk garis horizontal putih di tengah gambar.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
#     Pixel = unit terkecil penyusun citra. Resolusi = jumlah total pixel (lebar × tinggi). Semakin tinggi resolusi semakin banyak pixel gambar lebih detail/tajam tapi butuh memori & waktu proses lebih besar. Resolusi rendah gambar lebih kasar/blur tapi proses lebih cepat.

# %%
#TUGAS PRAKTIKUM D2
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


for y in range(tinggi):
  #membuat garis vertikal di tengah image
    image_3[y, int((lebar)/2)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Membuat garis diagonal menyilang (X)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
for y in range(tinggi):
    # Diagonal dari kiri-atas ke kanan-bawah
    x1 = int(y * (lebar / tinggi))
    if x1 < lebar:
        image_4[y, x1] = [255, 255, 255]
    # Diagonal dari kanan-atas ke kiri-bawah
    x2 = int((tinggi - 1 - y) * (lebar / tinggi))
    if x2 < lebar:
        image_4[y, x2] = [255, 255, 255]
final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x500>
# <PIL.Image.Image image mode=RGB size=1600x500>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_tugas3 = image_2.copy()

tinggi, lebar = image_tugas3.shape[:2]

# Menentukan panjang garis
panjang_garis = 150
start = int((lebar - panjang_garis) / 2)
end = start + panjang_garis

# Membuat garis horizontal
for y in range(start, end):
    image_tugas3[int(tinggi / 2), y] = [255, 255, 255]

final_frame_3 = cv.hconcat((image_2, image_tugas3))
cv2_imshow(final_frame_3)

image_tugas4 = image_2.copy()

# Menentukan ukuran kotak
ukuran_kotak = 80

# Menentukan posisi kotak secara manual
y = 120
x = 180

# Membuat kotak solid
for i in range(y, y + ukuran_kotak):
    for j in range(x, x + ukuran_kotak):
        image_tugas4[i, j] = [255, 255, 255]

# Menggabungkan dan menampilkan gambar
final_frame_4 = cv.hconcat((image_2, image_tugas4))
cv2_imshow(final_frame_4)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x500>
# <PIL.Image.Image image mode=RGB size=1600x500>
